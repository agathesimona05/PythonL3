# %%
class PriceSeries:
    TRADING_DAYS_PER_YEAR=252
    def __init__(self, values: list[float], name: str | None) -> None:
        self.name = name
        self.values = list(values)

def __repr__(self):
    return f"TimeSeries({self.name!r}, {self.values!r})"

def __str__(self):
    if self.values:
        return f"{self.name}: {self.values[-1]: .2f}(latest)
# Out:
# Traceback (most recent call last):
#   File "/Users/agathesimona/.vscode/extensions/ms-python.python-2026.0.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 12
#     return f"{self.name}: {self.values[-1]: .2f}(latest)
#            ^
# SyntaxError: unterminated f-string literal (detected at line 12)

# %%
class PriceSeries:
    TRADING_DAYS_PER_YEAR=252
    def __init__(self, values: list[float], name: str | None) -> None:
        self.name = name
        self.values = list(values)

def __repr__(self):
    return f"TimeSeries({self.name!r}, {self.values!r})"

def __str__(self):
    if self.values:
        return f"{self.name}: {self.values[-1]: .2f}(latest)"

# %%
ps = PriceSeries([100, 101, 102], "Apple")

# %%
str(ps)

# %%
repr(ps)

# %%
str(ps)

# %%
ps = PriceSeries([100, 101, 102], "Apple")
str(ps)
repr(ps)

# %%
class PriceSeries:
    TRADING_DAYS_PER_YEAR=252
    def __init__(self, values: list[float], name: str | None) -> None:
        self.name = name
        self.values = list(values)

def __repr__(self):
    return f"TimeSeries({self.name!r}, {self.values!r})"

def __str__(self):
    if self.values:
        return f"{self.name}: {self.values[-1]: .2f}(latest)"
    
def __len__(self):
    return len(self.values)

# %%
ps = PriceSeries([100, 101, 102], "Apple")
str(ps)
repr(ps)

# %%
ps = PriceSeries([100, 101, 102], "Apple")

# %%
repr(ps)

# %%
str(ps)

# %%
import math
class PriceSeries:
    TRADING_DAYS_PER_YEAR=252
    def __init__(self, values: list[float], name: str | None) -> None:
        self.name = name
        self.values = list(values)

    def __repr__(self):
        return f"TimeSeries({self.name!r}, {self.values!r})"

    def __str__(self):
        if self.values:
            return f"{self.name}: {self.values[-1]: .2f}(latest)"
    
    def __len__(self):
        return len(self.values)

    def get_linear_return(self, t):
        return (self.values[t]- self.values[t-1])/ self.values[t-1]

    def get_log_return(self, t):
        return math.log(self.value[t]/self.vamlues[t-1])

# %%
ps = PriceSeries([100, 101, 102], "Apple")

# %%
repr(ps)
# Out:
# TimeSeries('Apple', [100, 101, 102])

# %%
str(ps)
# Out:
# Apple:  102.00(latest)

# %%
len(ps)
# Out:
# 3

# %%
ps.get_linear_return(2)
# Out:
# 0.009900990099009901

# %%
x=5

# %%
y=4

# %%
x+y
# Out:
# 9

# %%
price[1:4]
# Out:
# Traceback (most recent call last):
#   File "/Users/agathesimona/.vscode/extensions/ms-python.python-2026.0.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# NameError: name 'price' is not defined. Did you mean: 'print'?
